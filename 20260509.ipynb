# %% [markdown]
# <a href="https://colab.research.google.com/github/89ken/raspbeery_gemini/blob/main/20260509.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ### 這是第一節上課講義
# 下面是數學運算介紹
#
# 先介紹*變數*,**數學運算式**
#
# #### 專有名詞介紹
#
# -變數
#
# -數學運算式
#
# 1.運算子,運算元
#
# 2.運算式,敘述式
